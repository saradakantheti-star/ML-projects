# %% [markdown]
# <a href="https://colab.research.google.com/github/saradakantheti-star/ML-projects/blob/main/VectorsPlotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.quiver(0,0,3,4,scale_units='xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,-3,4,scale_units='xy',angles='xy',scale=1,color='g')
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
def plot_vectors(vecs):
  colors = ['r','g','b','y']
  i=0
  for vec in vecs:
    plt.quiver(vec[0],vec[1],vec[2],vec[3],scale_units='xy',angles='xy',scale=1,color=colors[i])
    i +=1
  plt.xlim(-10,10)
  plt.ylim(-10,10)
  plt.show()

# %%
plot_vectors([(0,0,3,4), (0,0,-3,4),(0,0,-3,-2),(0,0,4,-1)])

# %%
vecs = [np.asarray([0,0,3,4]), np.asarray([0,0,-3,4]),np.asarray([0,0,-3,-2]),np.asarray([0,0,4,-1])]

# %%
plot_vectors([vecs[0],vecs[3]])

# %%
vecs[0]+vecs[3]
# Out:
# array([0, 0, 7, 3])

# %%
plot_vectors([vecs[0],vecs[3],vecs[0]+vecs[3]])
